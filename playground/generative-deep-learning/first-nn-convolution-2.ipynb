# %%
import numpy as np
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.layers import Input, Flatten, Dense, Conv2D, BatchNormalization, Dropout, LeakyReLU, Activation
from keras.models import Model
from keras.optimizers import Adam

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
((x_train.shape, y_train.shape), (x_test.shape, y_test.shape))
# Out:
# (((50000, 32, 32, 3), (50000, 1)), ((10000, 32, 32, 3), (10000, 1)))

# %%
plt.figure(figsize=(5, 5))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(x_train[i])
    plt.title(int(y_train[i]))
    plt.axis("off")

# %%
NUM_CLASSES = 10

# %%
# data comes in integers between 0 and 255 for each pixel channel
# convert to a range between –1 to 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train[0][0]
# Out:
# array([[0.23137255, 0.24313726, 0.24705882],
#        [0.16862746, 0.18039216, 0.1764706 ],
#        [0.19607843, 0.1882353 , 0.16862746],
#        [0.26666668, 0.21176471, 0.16470589],
#        [0.38431373, 0.28627452, 0.20392157],
#        [0.46666667, 0.35686275, 0.24705882],
#        [0.54509807, 0.41960785, 0.29411766],
#        [0.5686275 , 0.43137255, 0.3137255 ],
#        [0.58431375, 0.45882353, 0.34901962],
#        [0.58431375, 0.47058824, 0.3647059 ],
#        [0.5137255 , 0.40392157, 0.3019608 ],
#        [0.49019608, 0.3882353 , 0.29803923],
#        [0.5568628 , 0.4509804 , 0.35686275],
#        [0.5647059 , 0.4392157 , 0.3372549 ],
#        [0.5372549 , 0.4117647 , 0.30980393],
#        [0.5058824 , 0.38039216, 0.2784314 ],
#        [0.5372549 , 0.41568628, 0.30980393],
#        [0.5254902 , 0.41568628, 0.29803923],
#        [0.4862745 , 0.38039216, 0.2509804 ],
#        [0.54509807, 0.44313726, 0.30588236],
#        [0.54509807, 0.4392157 , 0.29411766],
#        [0.52156866, 0.4117647 , 0.27058825],
#        [0.53333336, 0.4117647 , 0.2901961 ],
#        [0.54509807, 0.42352942, 0.3019608 ],
#        [0.59607846, 0.47058824, 0.34901962],
#        [0.6392157 , 0.5137255 , 0.39215687],
#        [0.65882355, 0.53333336, 0.42352942],
#        [0.62352943, 0.5058824 , 0.4       ],
#        [0.61960787, 0.50980395, 0.40784314],
#        [0.61960787, 0.5176471 , 0.42352942],
#        [0.59607846, 0.49019608, 0.4       ],
#        [0.5803922 , 0.4862745 , 0.40392157]], dtype=float32)

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
# change the integer labeling of the images to one-hot-encoded vectors
y_train = to_categorical(y_train, NUM_CLASSES)
y_test = to_categorical(y_test, NUM_CLASSES)
y_train[0][0]
# Out:
# 0.0

# %%
(y_train.shape, y_test.shape)
# Out:
# ((50000, 10), (10000, 10))

# %%
input_layer = Input(shape=(32,32, 3))
input_layer.shape
# Out:
# TensorShape([None, 32, 32, 3])

# %%
x = Conv2D(
    filters=32,
    kernel_size=3,
    strides=1,
    padding='same', # the padding allows the kernel to extend over the edge of the image
)(input_layer)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# %%
x = Conv2D(filters=32, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2D(filters=64, kernel_size=3, strides=1, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

x = Conv2D(filters=64, kernel_size=3, strides=2, padding='same')(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)

# %%
x = Flatten()(x)

# %%
x = Dense(units=24)(x)
x = BatchNormalization()(x)
x = LeakyReLU()(x)
x = Dropout(rate=0.5)(x)

# %%
x = Dense(units=NUM_CLASSES)(x)
output_layer = Activation('softmax')(x)
output_layer.shape
# Out:
# TensorShape([None, 10])

# %%
model = Model(input_layer, output_layer)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_13 (Bat  (None, 32, 32, 32)       128
#  chNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 32, 32, 32)        0
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 32)        9248
#
#  batch_normalization_14 (Bat  (None, 16, 16, 32)       128
#  chNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 16, 16, 32)        0
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_15 (Bat  (None, 16, 16, 64)       256
#  chNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 16, 16, 64)        0
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 64)          36928
#
#  batch_normalization_16 (Bat  (None, 8, 8, 64)         256
#  chNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 8, 8, 64)          0
#
#  flatten_3 (Flatten)         (None, 4096)              0
#
#  dense_6 (Dense)             (None, 24)                98328
#
#  batch_normalization_17 (Bat  (None, 24)               96
#  chNormalization)
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 24)                0
#
#  dropout_3 (Dropout)         (None, 24)                0
#
#  dense_7 (Dense)             (None, 10)                250
#
#  activation_3 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 165,010
# Trainable params: 164,578
# Non-trainable params: 432
# _________________________________________________________________

# %%
opt = Adam(learning_rate=0.0005)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model.fit(
    x_train, # raw image data
    y_train, # hot encoded class labels
    batch_size=32, # how many observations (images) at each training step
                  # the larger the batch size, the more stable the gradient calculation, but the slower each training step
    epochs=20,
    shuffle=True, # batches should be randomly drawn from the training data
    validation_data = (x_test, y_test)
)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.7144 - accuracy: 0.3942 - val_loss: 1.3211 - val_accuracy: 0.5393
# Epoch 2/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.3914 - accuracy: 0.5073 - val_loss: 1.1743 - val_accuracy: 0.5921
# Epoch 3/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.2408 - accuracy: 0.5663 - val_loss: 1.0564 - val_accuracy: 0.6375
# Epoch 4/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.1535 - accuracy: 0.5984 - val_loss: 1.0622 - val_accuracy: 0.6285
# Epoch 5/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0971 - accuracy: 0.6174 - val_loss: 0.9444 - val_accuracy: 0.6724
# Epoch 6/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0398 - accuracy: 0.6409 - val_loss: 0.9443 - val_accuracy: 0.6680
# Epoch 7/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 1.0080 - accuracy: 0.6507 - val_loss: 0.8787 - val_accuracy: 0.6857
# Epoch 8/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9743 - accuracy: 0.6643 - val_loss: 0.9439 - val_accuracy: 0.6619
# Epoch 9/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9395 - accuracy: 0.6753 - val_loss: 0.8931 - val_accuracy: 0.6890
# Epoch 10/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.9068 - accuracy: 0.6865 - val_loss: 0.8217 - val_accuracy: 0.7117
# Epoch 11/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8854 - accuracy: 0.6926 - val_loss: 0.7856 - val_accuracy: 0.7283
# Epoch 12/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8592 - accuracy: 0.7049 - val_loss: 0.8023 - val_accuracy: 0.7257
# Epoch 13/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.8398 - accuracy: 0.7108 - val_loss: 0.7830 - val_accuracy: 0.7323
# Epoch 14/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8205 - accuracy: 0.7165 - val_loss: 0.7622 - val_accuracy: 0.7368
# Epoch 15/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8018 - accuracy: 0.7219 - val_loss: 0.7618 - val_accuracy: 0.7368
# Epoch 16/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7830 - accuracy: 0.7283 - val_loss: 0.7703 - val_accuracy: 0.7355
# Epoch 17/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7625 - accuracy: 0.7327 - val_loss: 0.8286 - val_accuracy: 0.7188
# Epoch 18/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7520 - accuracy: 0.7410 - val_loss: 0.8137 - val_accuracy: 0.7167
# Epoch 19/20
# 1563/1563 [==============================] - 6s 4ms/step - loss: 0.7363 - accuracy: 0.7432 - val_loss: 0.8327 - val_accuracy: 0.7087
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7185 - accuracy: 0.7527 - val_loss: 0.7883 - val_accuracy: 0.7306

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.7883 - accuracy: 0.7306
# [0.7883377075195312, 0.7305999994277954]

# %%
CLASSES = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog' , 'frog', 'horse', 'ship', 'truck'])
preds = model.predict(x_test)
preds_single = CLASSES[np.argmax(preds, axis = -1)]
actual_single = CLASSES[np.argmax(y_test, axis = -1)]
# Out:
# 313/313 [==============================] - 1s 1ms/step

# %%
n_to_show = 10
indices = np.random.choice(range(len(x_test)), n_to_show)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i, idx in enumerate(indices):
    img = x_test[idx]
    ax = fig.add_subplot(1, n_to_show, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, 'pred = ' + str(preds_single[idx]), fontsize=10 , ha='center', transform=ax.transAxes)
    ax.text(0.5, -0.7, 'act = ' + str(actual_single[idx]), fontsize=10 , ha='center', transform=ax.transAxes)
    ax.imshow(img)

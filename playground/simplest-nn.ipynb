# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2022-09-25 22:04:26.127820: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-25 22:04:26.250548: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-25 22:04:26.644926: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# ...

# %%
EPOCHS = 500

# %%
# Y = 2x – 1
def f(_x: float):
  return 2 * _x - 1

# %%
x = [-1.0, 0.0, 1.0, 2.0, 3.0, 4.0]
y = [-3.0, -1.0, 1.0, 3.0, 5.0, 7.0]

# %%
layers = [
  Dense(units=1, input_shape=[1])
]
model = Sequential(layers)
model.compile(optimizer='sgd', loss='mean_squared_error')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-25 22:04:27.344573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-25 22:04:27.367922: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %%
xs = np.array(x, dtype=float)
ys = np.array(y, dtype=float)
(xs.shape, ys.shape)
# Out:
# ((6,), (6,))

# %%
model.fit(xs, ys, epochs=EPOCHS)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 722ms/step - loss: 1.0914
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9877
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9034
# Epoch 4/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8345
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7778
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7307
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6912
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6577
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6290
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6041
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5823
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5630
# ...

# %%
_input = 10.
prediction = model.predict([_input])
manual_prediction = f(_input)
y1 = prediction[0][0]
y2 = manual_prediction
print(y1, y2)
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 18.986544 19.0

# %%
close_prediction = np.isclose(y1, y2, rtol=0.05)
print(f'Is the prediction close to the known answer? {"Yes" if close_prediction else "No"}')
# Out:
# Is the prediction close to the known answer? Yes
